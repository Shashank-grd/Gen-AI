# %%
# !pip install google.generativeai langchain langchain_community langchain_core
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 810.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.9/399.9 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.2/292.2 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
import os
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

# %%
os.environ["GOOGLE_API_KEY"]=GOOGLE_API_KEY

# %%
import os
import google.generativeai as genai
from PIL import Image
import time

genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-1.5-flash')
def get_gemini_response(input_prompt, image):
    start_time = time.time()

    token_prompt = model.count_tokens([input_prompt,image])
    print(token_prompt)
    #token_image = model.count_tokens([image])
    #print(token_image)

    response = model.generate_content([input_prompt, image])
    end_time = time.time()
    training_time = end_time - start_time
    print(training_time)
    return response.text

def input_image_setup(file_path):
    try:
        image = Image.open(file_path)
        #image = image.resize((150, 150))
        return image
    except FileNotFoundError:
        raise FileNotFoundError("File not found. Please check the file path.")

# %%
input_prompt = " "
uploaded_file_path = "/content/data/download (4).jpeg"

image_data = input_image_setup(uploaded_file_path)

response = get_gemini_response(input_prompt, image_data)

print(response)

# %%
input_prompt = "i am  a frontend developer i need to put this image in asset folder give me a only one name "
file_names = os.listdir('/content/images')
for file_name in file_names :
  image= f'/content/images/{file_name}'
  image_data = input_image_setup(image)
  response = get_gemini_response(input_prompt, image_data)
  print(response)
# Out:
# total_tokens: 280
#
# 5.968391180038452
# `purple-flower.jpg`
#
# total_tokens: 280
#
# 3.280510663986206
# "girl-painted-hands.jpg"
#
# total_tokens: 280
#
# 2.9583187103271484
# autumn-leaf.jpg
#
# total_tokens: 280
#
# 3.366206645965576
# kia-ev6.jpg
#
# total_tokens: 280
#
# 3.260772466659546
# google-play-store-logo.png
# total_tokens: 280
#
# 3.235808849334717
# shiva.jpg
#
# total_tokens: 280
#
# 3.280061960220337
# **autumn-road.jpg**
#
# total_tokens: 280
#
# 3.5832691192626953
# taj-mahal.jpg
#
# total_tokens: 280
#
# 3.130579948425293
# mountain-field-tree.jpg
